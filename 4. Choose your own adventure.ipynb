# %%
name = input('Type your name: ')

print ('Welcome to this adventure,', name, '!')

answer = input('You are on a dirt road. It has come to an end and you can go to left or right. Which way would you like to go? Type "left" or "right". ').lower()

if answer == 'left':
    answer = input('You reached a river. You can walk around it or swim across. Type "walk" or "swim" to choose one of the paths: ')
    if answer == 'swim':
        print('You swam across and were eaten by an alligator. You lost!')
    elif answer == 'walk':
        print('You walked for many miles, ran out of water and lost the game.')
    else:
        print('Not a valid option. You lost.')

    
elif answer == 'right':
    answer = input('You have reached a bridge which looks wobbly. Do you want to cross it or head back? Type "cross" or "back". ')
    
    if answer == 'cross':
        print('You crossed the bridge and meet a stranger. Do you wanna talk to them? Type "Yes" or "No". ')
        
        
        if answer == 'yes':
            print('The stranger gives you a lot of gold. You win!')

        elif answer == 'no':
            print('The stranger is offended. You lost!')

        else:
            print('Not a valid option. You lost.')
            
    
    else:
        print('Not a valid option. You lost.')

        
    if answer == 'back':
        print('You went back to the main road. You can now decide to drive back.')
    else:
        print('Not a valid option. You lost.')


else:
    print('Not a valid option. You lost.')

print ('Thank you for trying,', name)
# Out:
# Type your name:  Isha
# Welcome to this adventure, Isha !
# You are on a dirt road. It has come to an end and you can go to left or right. Which way would you like to go? Type "left" or "right".  left
# You reached a river. You can walk around it or swim across. Type "walk" or "swim" to choose one of the paths:  walk
# You walked for many miles, ran out of water and lost the game.
# Thank you for trying Isha

# %%
name = input('Type your name: ')

print ('Welcome', name, 'to this adventure!')

answer = input('You are on a dirt road. It has come to an end and you can go to left or right. Which way would you like to go? Type "left" or "right". ').lower()

if answer == 'left':
    answer = input('You reached a river. You can walk around it or swim across. Type "walk" or "swim" to choose one of the paths: ').lower()
    if answer == 'swim':
        print('You swim across and were eaten by an alligator')
    elif answer == 'walk':
        print('You walked for many miles, ran out of water and lost the game.')
    else:
        print('Not a valid option. You lost.')

    
elif answer == 'right':
    answer = input('You have reached a bridge which looks wobbly. Do you want to cross it or head back? Type "cross" or "back". ').lower()
    
    if answer == 'cross':
       answer = input('You crossed the bridge and met a stranger. Do you wanna talk to them? Type "Yes" or "No". ').lower()
       if answer == 'yes':
        print('The stranger gave you a lot of gold. You won!')

       elif answer == 'no':
        print('The stranger is offended. You lost!')
       else:
        print('Not a valid option. You lost.')

    elif answer == 'back':
        print('You went back to the main road. You can now drive back home.')
    
    else:
        print('Not a valid option. You lost.')


else:
    print('Not a valid option. You lost.')

print ('Thank you for trying,', name)
# Out:
# Type your name:  Vishaal
# Welcome Vishaal to this adventure!
# You are on a dirt road. It has come to an end and you can go to left or right. Which way would you like to go? Type "left" or "right".  right
# You have reached a bridge which looks wobbly. Do you want to cross it or head back? Type "cross" or "back".  cross
# You crossed the bridge and met a stranger. Do you wanna talk to them? Type "Yes" or "No".  yes
# The stranger gave you a lot of gold. You won!
# Thank you for trying, Vishaal
