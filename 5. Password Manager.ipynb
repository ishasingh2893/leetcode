# %%
# Ask the user for a master password
master_pwd = input('What is the master password?')

def view():
    with open('passwords.txt', 'r') as f:  # check the with open function
        for line in f.readlines():
            data = line.rstrip() # to strip off the extra line we add after each entry
            user, passw = data.split('|')
            print('User:', user, '| Password:', passw)
def add():
    name = input('Account Name: ')
    pwd = input ('Password: ')
    with open('passwords.txt', 'a') as f: 
        f.write(name + "|" + pwd + '\n') #separates the name input from the password input with the vertical bar and creates a new line


while True:
    mode = input('Would you like to add a new password or view an existing one? Type "View" or "Add". Press Q to quit').lower()
    if mode == 'q':
        break
    
    if mode == 'view':
       view()
    elif mode == 'add':
       add()
    else:
       print ('Invalid mode')
       continue
# Out:
# What is the master password? msh
# Would you like to add a new password or view an existing one? Type "View" or "Add". Press Q to quit add
# Account Name:  gerg
# Password:  grgr
# Would you like to add a new password or view an existing one? Type "View" or "Add". Press Q to quit add
# Account Name:  gerg
# Password:  xdsa
# Would you like to add a new password or view an existing one? Type "View" or "Add". Press Q to quit view
# User: gerg Password: grgr
# User: gerg Password: xdsa
# Would you like to add a new password or view an existing one? Type "View" or "Add". Press Q to quit q
