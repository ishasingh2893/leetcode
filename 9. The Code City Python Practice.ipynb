# %% [markdown]
# Create a python program that takes user input and prints it

# %%
user_input = input('Hi there! How are you feeling today? (Enter Perfect/Good/Fine): ')
print(user_input)
# Out:
# Hi there! How are you feeling today? (Enter Perfect/Good/Fine):  good
# good

# %% [markdown]
# Determine if the user input is even or odd

# %%
number = int(input('Enter the number: '))

if number % 2 == 0:
    print('The number is even.')
else:
    print('The number is odd.')
# Out:
# Enter the number:  7
# The number is odd.

# %% [markdown]
# Convert C to F

# %%
def temp_converter(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

while True:
    temperature = input("Enter temperature in °C or Q to quit: ").lower()

    if temperature == 'q':
        print("Thanks for playing!")
        break

    try:
        temperature = float(temperature)
        converted_temp = temp_converter(temperature)
        print(f"{temperature}°C = {converted_temp}°F")

    except ValueError:
        print("Please enter a valid number or Q to quit.")
# Out:
# Enter temperature in °C or Q to quit:  30
# 30.0°C = 86.0°F
# Enter temperature in °C or Q to quit:  38
# 38.0°C = 100.4°F
# Enter temperature in °C or Q to quit:  23
# 23.0°C = 73.4°F
# Enter temperature in °C or Q to quit:  19
# 19.0°C = 66.2°F
# Enter temperature in °C or Q to quit:  20
# 20.0°C = 68.0°F
# Enter temperature in °C or Q to quit:  q
# Thanks for playing!

# %%
def temp_converter(temperature):
    fahrenheit = (temperature * 9/5) + 32
    return fahrenheit

while True:
    temperature = input("Enter temperature in °C or Q to quit: ").lower()

    if temperature == 'q':
        print("Thanks for playing!")
        break

    try:
        temperature = float(temperature)
        converted_temp = temp_converter(temperature)
        print(f"{temperature}°C = {converted_temp}°F")

    except ValueError:
        print("Please enter a valid number or Q to quit.")
# Out:
# Enter temperature in °C or Q to quit:  30
# 30.0°C = 86.0°F
# Enter temperature in °C or Q to quit:  20
# 20.0°C = 68.0°F
# Enter temperature in °C or Q to quit:  10
# 10.0°C = 50.0°F
# Enter temperature in °C or Q to quit:  q
# Thanks for playing!

# %% [markdown]
# Drawing pyramids

# %%
rows = 10

for i in range(1, rows + 1):
    # print spaces
    print(' ' * (rows-i), end = '')
    # print asterisks
    print('*' * (2*i - 1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
rows = 10

for i in range(1, rows + 1):
    stars = '*' * (2 * i - 1)
    print(stars.center(2 * rows - 1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
rows = 10

for i in range(1, rows+1):
    print(('★' * (2*i - 1)).center(2*rows - 1))
# Out:
#          ★
#         ★★★
#        ★★★★★
#       ★★★★★★★
#      ★★★★★★★★★
#     ★★★★★★★★★★★
#    ★★★★★★★★★★★★★
#   ★★★★★★★★★★★★★★★
#  ★★★★★★★★★★★★★★★★★
# ★★★★★★★★★★★★★★★★★★★

# %% [markdown]
# Take a string from the user and reverse it

# %%
original_string = input('Enter your message: ')

reverse_string = original_string[ : : -1]
print(reverse_string)
# Out:
# Enter your message:  Oh, hello there!
# !ereht olleh ,hO

# %% [markdown]
# Prime number check
